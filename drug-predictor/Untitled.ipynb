# %%
catalog.list()
# Out:
# ['gitter',
#  'drugbank',
#  'pubchem',
#  'processed_gitter',
#  'companies',
#  'reviews',
#  'shuttles',
#  'preprocessed_companies',
#  'preprocessed_shuttles',
#  'model_input_table',
#  'regressor',
#  'parameters',
#  'params:gitter',
#  'params:gitter.irrelevant_columns',
#  'params:gitter.columns_to_drop',
#  'params:gitter.columns_to_rename',
#  'params:gitter.columns_to_rename.XLogP',
#  'params:matc_gitter_conversion',
#  'params:matc_gitter_conversion.hematologic',
#  'params:matc_gitter_conversion.cardio',
#  'params:matc_gitter_conversion.antiinfective',
#  'params:matc_gitter_conversion.cns',
#  'params:matc_gitter_conversion.antineoplastic',
#  'params:matc_gitter_conversion.reproductivecontrol',
#  'params:matc_gitter_conversion.dermatologic',
#  'params:matc_gitter_conversion.antiinflammatory',
#  'params:matc_gitter_conversion.respiratorysystem',
#  'params:matc_gitter_conversion.gastrointestinal',
#  'params:matc_gitter_conversion.lipidregulating',
# ...

# %%
gitter = catalog.load('processed_gitter')
# Out:
# [07/20/23 18:55:09] INFO     Loading data from 'processed_gitter' (CSVDataSet)...               ]8;id=114047;file://C:\Users\josin\anaconda3\envs\kedro-environment\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=993285;file://C:\Users\josin\anaconda3\envs\kedro-environment\lib\site-packages\kedro\io\data_catalog.py#345\345]8;;\

# %%
gitter
# Out:
#             CID  HBondAcceptorCount  HBondDonorCount
# 0         24769                   2                0  \
# 1     134694070                   9                6
# 2          5121                   2                0
# 3       4660557                   1                1
# 4        122175                   2                2
# ...         ...                 ...              ...
# 6930       9231                   0                0
# 6931    3038520                   6                1
# 6932      88747                   4                1
# 6933   16640802                   2                1
# 6934   20068539                   2                0
#
#                                          IsomericSMILES  MolecularWeight
# 0                            CN(C)CCCCCCN(C)C.C(CBr)CBr          374.205  \
# 1     C1CN=C(N1)NC2=C(C3=NC=CN=C3C=C2)Br.[C@@H](C(C(...          442.226
# 2                        C1CSC2=NC(CN21)C3=CC=C(C=C3)Br          283.187
# ...

# %%
companies.head()
# Out:
#       id company_rating       company_location  total_fleet_count
# 0  35029           100%                   Niue                4.0  \
# 1  30292            67%               Anguilla                6.0
# 2  19032            67%     Russian Federation                4.0
# 3   8238            91%               Barbados               15.0
# 4  30342            NaN  Sao Tome and Principe                2.0
#
#   iata_approved
# 0             f
# 1             f
# 2             f
# 3             t
# 4             t

# %%
shuttles.head()
# Out:
#       id       shuttle_location shuttle_type engine_type       engine_vendor
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services  \
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew d_check_complete
# 0      1.0                   2              strict   1.0                f  \
# 1      1.0                   2              strict   1.0                t
# 2      1.0                   2            moderate   0.0                f
# 3      3.0                   6              strict   3.0                f
# 4      2.0                   4              strict   2.0                f
#
#   moon_clearance_complete     price  company_id
# ...

# %%
companies['id'].nunique()
# Out:
# 50098

# %%
df_reviews = catalog.load('reviews')
# Out:
# [07/18/23 20:11:11] INFO     Loading data from 'reviews' (CSVDataSet)...                        ]8;id=665884;file://C:\Users\josin\anaconda3\envs\kedro-environment\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=336045;file://C:\Users\josin\anaconda3\envs\kedro-environment\lib\site-packages\kedro\io\data_catalog.py#345\345]8;;\

# %%
df_reviews.head()
# Out:
#    shuttle_id  review_scores_rating  review_scores_comfort
# 0       63561                  97.0                   10.0  \
# 1       36260                  90.0                    8.0
# 2       57015                  95.0                    9.0
# 3       14035                  93.0                   10.0
# 4       10036                  98.0                   10.0
#
#    review_scores_amenities  review_scores_trip  review_scores_crew
# 0                      9.0                10.0                10.0  \
# 1                      9.0                10.0                 9.0
# 2                     10.0                 9.0                10.0
# 3                      9.0                 9.0                 9.0
# 4                     10.0                10.0                10.0
#
#    review_scores_location  review_scores_price  number_of_reviews
# 0                     9.0                 10.0                133  \
# 1                     9.0                  9.0                  3
# ...

# %%
import pandas as pd

# %%
gitter = pd.read_csv('processed_gitter.csv')

# %%
pubchem = pd.read_csv('processed_pubchem.csv')

# %%
gitter.head(3)
# Out:
#          CID  HBondAcceptorCount  HBondDonorCount
# 0      24769                   2                0  \
# 1  134694070                   9                6
# 2       5121                   2                0
#
#                                       IsomericSMILES  MolecularWeight  LogP
# 0                         CN(C)CCCCCCN(C)C.C(CBr)CBr          374.205   NaN  \
# 1  C1CN=C(N1)NC2=C(C3=NC=CN=C3C=C2)Br.[C@@H](C(C(...          442.226   NaN
# 2                     C1CSC2=NC(CN21)C3=CC=C(C=C3)Br          283.187   2.5
#
#    RuleFive MATC_Code_Short            MATC_Code_Explanation
# 0         1               B   BLOOD AND BLOOD FORMING ORGANS
# 1         0               C            CARDIOVASCULAR SYSTEM
# 2         1               J  ANTIINFECTIVES FOR SYSTEMIC USE

# %%
pubchem.head(3)
# Out:
#    CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0    1                   4                0           203.24   0.4  \
# 1  119                   3                2           103.12  -3.2
# 2  137                   4                2           131.13  -3.8
#
#                      IsomericSMILES  RuleFive MATC_Code_Short
# 0  CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C         1               N  \
# 1                      C(CC(=O)O)CN         1               N
# 2                 C(CC(=O)O)C(=O)CN         1               L
#
#                         MATC_Code_Explanation
# 0                              NERVOUS SYSTEM
# 1                              NERVOUS SYSTEM
# 2  ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS
