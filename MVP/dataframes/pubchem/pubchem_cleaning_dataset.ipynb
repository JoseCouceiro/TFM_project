# %%
import os
import json
import numpy as np
import pandas as pd

# %%
drugs = pd.read_csv('pubchem_dataset_label_clean.csv')

# %%
# Set lipinski rules
hdonor = drugs['HBondDonorCount'] < 6
haccept = drugs['HBondAcceptorCount'] < 10
mw = drugs['MolecularWeight'] < 500
clogP = drugs['LogP'] < 5
# Apply rules to dataframe
drugs['RuleFive'] = np.where(((hdonor & haccept & mw) | (hdonor & haccept & clogP) | (hdonor & mw & clogP) | (haccept & mw & clogP)), 1, 0)

# %%
with open(os.path.join('..','dataframes_resources','dataframes_props.json')) as file:
    res = json.load(file)
column_order = res['column_order']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 with open(os.path.join('..','dataframes_resources','dataframes_props.json')) as file:
#       2     res = json.load(file)
# ----> 3 column_order = res['column_order']
#
# KeyError: 'column_order'

# %%
drugs = drugs[column_order]
drugs.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 drugs = drugs[column_order]
#       2 drugs.head()
#
# NameError: name 'column_order' is not defined

# %%
drugs['ATC_Code'] = drugs['ATC_Code'].str[0]

# %%
drugs.head(100)
# Out:
#      CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0      1                   4                0           203.24  0.40  \
# 1    119                   3                2           103.12 -3.17
# 2    137                   4                2           131.13 -1.50
# 3    176                   2                1            60.05 -0.17
# 4    187                   2                0           146.21  0.20
# ..   ...                 ...              ...              ...   ...
# 95  2164                   3                2           226.27  2.07
# 96  2165                   4                2           355.90  3.70
# 97  2170                   3                1           313.80  3.40
# 98  2179                   6                2           393.50  3.80
# 99  2187                   4                0           293.40  1.58
#
#     RuleFive                                     IsomericSMILES ATC_Code
# 0          1                   CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C        N  \
# 1          1                                       C(CC(=O)O)CN        N
# 2          1                                  C(CC(=O)O)C(=O)CN        L
# 3          1                                            CC(=O)O        G
# 4          1                               CC(=O)OCC[N+](C)(C)C        S
# ..       ...                                                ...      ...
# 95         1                      CCC1(C(=O)NC(=O)NC1=O)CCC(C)C        N
# 96         1   CCN(CC)CC1=C(C=CC(=C1)NC2=C3C=CC(=CC3=NC=C2)Cl)O        P
# 97         1         C1CN(CCN1)C2=NC3=CC=CC=C3OC4=C2C=C(C=C4)Cl        N
# 98         1  COC1=C(C=CC(=C1)NS(=O)(=O)C)NC2=C3C=CC=CC3=NC4...        L
# 99         1      CC(C)(C#N)C1=CC(=CC(=C1)CN2C=NC=N2)C(C)(C)C#N        L
#
#    ATC_Code_Short                               ATC_Code_Explanation
# 0               N                                     nervous system
# 1               N                                     nervous system
# 2               L         antineoplastic and immunomodulating agents
# 3               G             genito urinary system and sex hormones
# 4               S                                     sensory organs
# ..            ...                                                ...
# 95              N                                     nervous system
# 96              P  antiparasitic products, insecticides and repel...
# 97              N                                     nervous system
# 98              L         antineoplastic and immunomodulating agents
# 99              L         antineoplastic and immunomodulating agents
#
# [100 rows x 10 columns]

# %%
drugs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4375 entries, 0 to 4374
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CID                   4375 non-null   int64
#  1   HBondAcceptorCount    4375 non-null   int64
#  2   HBondDonorCount       4375 non-null   int64
#  3   MolecularWeight       4375 non-null   float64
#  4   LogP                  3809 non-null   float64
#  5   RuleFive              4375 non-null   int32
#  6   IsomericSMILES        4375 non-null   object
#  7   ATC_Code              4375 non-null   object
#  8   ATC_Code_Short        4375 non-null   object
#  9   ATC_Code_Explanation  4375 non-null   object
# dtypes: float64(2), int32(1), int64(3), object(4)
# memory usage: 324.8+ KB

# %%
drugs.to_csv(os.path.join('pubchem_dataset_label_clean.csv'), index= False)
