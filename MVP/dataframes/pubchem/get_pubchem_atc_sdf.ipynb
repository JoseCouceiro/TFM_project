# %%
import os
import json
import requests as rq
import re
import numpy as np
import pandas as pd
import pubchempy as pcp
import sdf

# %%
pubchem = pd.read_csv('PubChem_compound_list.csv')

# %%
with open(os.path.join('..','dataframes_resources','dataframes_props.json')) as file:
    res = json.load(file)
column_order = res['column_order_dbs']

# %%
column_order
# Out:
# ['CID',
#  'HBondAcceptorCount',
#  'HBondDonorCount',
#  'IsomericSMILES',
#  'MolecularWeight',
#  'LogP',
#  'RuleFive',
#  'MATC_Code_Short',
#  'MATC_Code_Explanation']

# %%
pubchem.columns
# Out:
# Index(['cid', 'cmpdname', 'cmpdsynonym', 'mw', 'mf', 'polararea', 'complexity',
#        'xlogp', 'heavycnt', 'hbonddonor', 'hbondacc', 'rotbonds', 'inchi',
#        'isosmiles', 'canonicalsmiles', 'inchikey', 'iupacname', 'exactmass',
#        'monoisotopicmass', 'charge', 'covalentunitcnt', 'isotopeatomcnt',
#        'totalatomstereocnt', 'definedatomstereocnt', 'undefinedatomstereocnt',
#        'totalbondstereocnt', 'definedbondstereocnt', 'undefinedbondstereocnt',
#        'pclidcnt', 'gpidcnt', 'gpfamilycnt', 'neighbortype', 'meshheadings',
#        'annothits', 'annothitcnt', 'aids', 'cidcdate', 'sidsrcname', 'depcatg',
#        'annotation'],
#       dtype='object')

# %%
pubchem_select = pubchem[['cid', 'hbondacc', 'hbonddonor', 'mw', 'xlogp', 'isosmiles']]

# %%
pubchem_select
# Out:
#             cid  hbondacc  hbonddonor       mw  xlogp
# 0             1         4           0   203.24    0.4  \
# 1           119         3           2   103.12   -3.2
# 2           137         4           2   131.13   -3.8
# 3           174         2           2    62.07   -1.4
# 4           176         2           1    60.05   -0.2
# ...         ...       ...         ...      ...    ...
# 4479  168009818        70          58  4813.00   -6.8
# 4480  168012238        13           3   687.90    2.6
# 4481  168012331        16           4  1030.30    5.6
# 4482  168013289        56          24  2002.20  -10.5
# 4483  168013303        16           3   828.00    2.9
#
#                                               isosmiles
# 0                      CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C
# 1                                          C(CC(=O)O)CN
# 2                                     C(CC(=O)O)C(=O)CN
# 3                                                C(CO)O
# 4                                               CC(=O)O
# ...                                                 ...
# 4479  CCC(C)C(C(=O)NC(C)C(=O)NC(CCC(=O)N)C(=O)NC(CCC...
# 4480  C[C@@H]1C[C@@H]([C@H]([C@@H](O1)OC2[C@H](C[C@@...
# 4481  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C\[C@H](C[...
# 4482  C(CSC[C@@H]1[C@@H]2[C@@H]([C@H]([C@H](O1)O[C@@...
# 4483  C[C@@H]1C/C=C/C=C/[C@@H]([C@@H](CC([C@@H]([C@H...
#
# [4484 rows x 6 columns]

# %%
pubchem_select = pubchem_select.rename(columns={'cid': 'CID', 'hbondacc': 'HBondAcceptorCount', 'hbonddonor': 'HBondDonorCount', 'mw': 'MolecularWeight', 'xlogp': 'LogP', 'isosmiles': 'IsomericSMILES'})

# %%
pubchem_select
# Out:
#             CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0             1                   4                0           203.24   0.4  \
# 1           119                   3                2           103.12  -3.2
# 2           137                   4                2           131.13  -3.8
# 3           174                   2                2            62.07  -1.4
# 4           176                   2                1            60.05  -0.2
# ...         ...                 ...              ...              ...   ...
# 4479  168009818                  70               58          4813.00  -6.8
# 4480  168012238                  13                3           687.90   2.6
# 4481  168012331                  16                4          1030.30   5.6
# 4482  168013289                  56               24          2002.20 -10.5
# 4483  168013303                  16                3           828.00   2.9
#
#                                          IsomericSMILES
# 0                      CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C
# 1                                          C(CC(=O)O)CN
# 2                                     C(CC(=O)O)C(=O)CN
# 3                                                C(CO)O
# 4                                               CC(=O)O
# ...                                                 ...
# 4479  CCC(C)C(C(=O)NC(C)C(=O)NC(CCC(=O)N)C(=O)NC(CCC...
# 4480  C[C@@H]1C[C@@H]([C@H]([C@@H](O1)OC2[C@H](C[C@@...
# 4481  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C\[C@H](C[...
# 4482  C(CSC[C@@H]1[C@@H]2[C@@H]([C@H]([C@H](O1)O[C@@...
# 4483  C[C@@H]1C/C=C/C=C/[C@@H]([C@@H](CC([C@@H]([C@H...
#
# [4484 rows x 6 columns]

# %%
# Set lipinski rules
hdonor = pubchem_select['HBondDonorCount'] < 6
haccept = pubchem_select['HBondAcceptorCount'] < 10
mw = pubchem_select['MolecularWeight'] < 500
clogP = pubchem_select['LogP'] < 5

# %%
# Apply rules to dataframe
pubchem_select['RuleFive'] = np.where(((hdonor & haccept & mw) | (hdonor & haccept & clogP) | (hdonor & mw & clogP) | (haccept & mw & clogP)), 1, 0)

# %%
pubchem_select
# Out:
#             CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0             1                   4                0           203.24   0.4  \
# 1           119                   3                2           103.12  -3.2
# 2           137                   4                2           131.13  -3.8
# 3           174                   2                2            62.07  -1.4
# 4           176                   2                1            60.05  -0.2
# ...         ...                 ...              ...              ...   ...
# 4479  168009818                  70               58          4813.00  -6.8
# 4480  168012238                  13                3           687.90   2.6
# 4481  168012331                  16                4          1030.30   5.6
# 4482  168013289                  56               24          2002.20 -10.5
# 4483  168013303                  16                3           828.00   2.9
#
#                                          IsomericSMILES  RuleFive
# 0                      CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C         1
# 1                                          C(CC(=O)O)CN         1
# 2                                     C(CC(=O)O)C(=O)CN         1
# 3                                                C(CO)O         1
# 4                                               CC(=O)O         1
# ...                                                 ...       ...
# 4479  CCC(C)C(C(=O)NC(C)C(=O)NC(CCC(=O)N)C(=O)NC(CCC...         0
# 4480  C[C@@H]1C[C@@H]([C@H]([C@@H](O1)OC2[C@H](C[C@@...         0
# 4481  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C\[C@H](C[...         0
# 4482  C(CSC[C@@H]1[C@@H]2[C@@H]([C@H]([C@H](O1)O[C@@...         0
# 4483  C[C@@H]1C/C=C/C=C/[C@@H]([C@@H](CC([C@@H]([C@H...         0
#
# [4484 rows x 7 columns]

# %%
not_found = []

# %%
def get_atc_code(cid):
    
    url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/{cid}/JSON'
    response = rq.get(url)
    pat = r"\"[A-Z]\d{2}[A-Z]{2}\d{2}\""
    atc_code_found = re.search(pat, response.text)
    if atc_code_found:
        return atc_code_found.group(0).strip('"')
    else:
        not_found.append(cid)

# %%
def get_atc_code_json(cid):
    url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/{cid}/JSON'
    response = rq.get(url)
    pat = r"\"[A-Z]\d{2}[A-Z]{2}\d{2}\""
    atc_code_found = re.search(pat, response.text)
    if atc_code_found:
        return atc_code_found.group(0).strip('"')

# %%
pubchem_select['ATC_Code'] = pubchem_select['CID'].map(get_atc_code)

# %%
not_found
# Out:
# [174,
#  1972,
#  5581,
#  5826,
#  14956,
#  14960,
#  56494,
#  64655,
#  65430,
#  66274,
#  66376,
#  66380,
#  69438,
#  69439,
#  71180,
#  71184,
#  71368,
#  122051,
#  123829,
#  135326,
#  156375,
#  157443,
#  166973,
#  170848,
#  443997,
#  450503,
#  450510,
#  452949,
#  656666,
#  3086672,
#  5386092,
#  5388879,
#  5462076,
#  5702198,
#  5748852,
#  5771695,
#  6093445,
#  6328682,
#  6452753,
#  6455416,
#  6918077,
#  9834479,
#  9919339,
#  10103319,
#  10405586,
#  10869981,
#  11133125,
#  11306073,
#  11430828,
#  11431716,
#  11789360,
#  11954386,
#  16220016,
#  16667679,
#  22617237,
#  23663553,
#  23667636,
#  23690531,
#  23724931,
#  23863720,
#  44399170,
#  44421047,
#  46783367,
#  46783793,
#  49799974,
#  50986201,
#  52950901,
#  53486284,
#  56971651,
#  70957463,
#  71306412,
#  71311649,
#  71313388,
#  71661158,
#  72941734,
#  73438937,
#  76957057,
#  76962197,
#  76962714,
#  76963828,
#  76967078,
#  90478549,
#  91827561,
#  117587538,
#  117587627,
#  118705500,
#  121494118,
#  122197546,
#  122361636,
#  122362248,
#  131668620,
#  131668621,
#  131673845,
#  131674879,
#  131704315,
#  131704316,
#  131704321,
#  131704327,
#  134694302,
#  134719018,
#  135391140,
#  136226470,
#  136245567,
#  138059666,
#  138402789,
#  139246982,
#  145705939,
#  146019527,
#  146157396,
#  154572876,
#  154573754,
#  155491107,
#  155491161,
#  164886662,
#  165411920]

# %%
len(not_found)
# Out:
# 115

# %%
pubchem_select
# Out:
#             CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0             1                   4                0           203.24   0.4  \
# 1           119                   3                2           103.12  -3.2
# 2           137                   4                2           131.13  -3.8
# 3           174                   2                2            62.07  -1.4
# 4           176                   2                1            60.05  -0.2
# ...         ...                 ...              ...              ...   ...
# 4479  168009818                  70               58          4813.00  -6.8
# 4480  168012238                  13                3           687.90   2.6
# 4481  168012331                  16                4          1030.30   5.6
# 4482  168013289                  56               24          2002.20 -10.5
# 4483  168013303                  16                3           828.00   2.9
#
#                                          IsomericSMILES  RuleFive ATC_Code
# 0                      CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C         1  N06BX12
# 1                                          C(CC(=O)O)CN         1  N03AG03
# 2                                     C(CC(=O)O)C(=O)CN         1  L01XD04
# 3                                                C(CO)O         1     None
# 4                                               CC(=O)O         1  G01AD02
# ...                                                 ...       ...      ...
# 4479  CCC(C)C(C(=O)NC(C)C(=O)NC(CCC(=O)N)C(=O)NC(CCC...         0  A10BX16
# 4480  C[C@@H]1C[C@@H]([C@H]([C@@H](O1)OC2[C@H](C[C@@...         0  J01FA05
# 4481  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C\[C@H](C[...         0  L01XE09
# 4482  C(CSC[C@@H]1[C@@H]2[C@@H]([C@H]([C@H](O1)O[C@@...         0  V03AB35
# 4483  C[C@@H]1C/C=C/C=C/[C@@H]([C@@H](CC([C@@H]([C@H...         0  J01FA07
#
# [4484 rows x 8 columns]

# %%
pubchem_select['MATC_Code_Short'] = pubchem_select['ATC_Code'].str[0]

# %%
with open(os.path.join('..','dataframes_resources','dataframes_props.json')) as file:
    res = json.load(file)
matc_codes_explanation = res['matc_codes_explanation']

# %%
pubchem_select['MATC_Code_Explanation'] = pubchem_select['MATC_Code_Short'].map(matc_codes_explanation)

# %%
pubchem_select = pubchem_select.drop('ATC_Code', axis=1)

# %%
pubchem_select = pubchem_select[pubchem_select['MATC_Code_Short'].isna() == False]

# %%
pubchem_select.head()
# Out:
#    CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0    1                   4                0           203.24   0.4  \
# 1  119                   3                2           103.12  -3.2
# 2  137                   4                2           131.13  -3.8
# 4  176                   2                1            60.05  -0.2
# 5  187                   2                0           146.21   0.2
#
#                      IsomericSMILES  RuleFive MATC_Code_Short
# 0  CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C         1               N  \
# 1                      C(CC(=O)O)CN         1               N
# 2                 C(CC(=O)O)C(=O)CN         1               L
# 4                           CC(=O)O         1               G
# 5              CC(=O)OCC[N+](C)(C)C         1               S
#
#                         MATC_Code_Explanation
# 0                              NERVOUS SYSTEM
# 1                              NERVOUS SYSTEM
# 2  ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS
# 4      GENITO URINARY SYSTEM AND SEX HORMONES
# 5                              SENSORY ORGANS
