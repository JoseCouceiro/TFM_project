# %%
import os
import json
import requests as rq
import re
import numpy as np
import pandas as pd
import pubchempy as pcp
import sdf

# %%
pubchem = pd.read_csv('C:/Users/josin/GitRepositories/TFM_project/MVP/dataframes/mock_dataframes/mock_pubchem.csv')

# %%
with open(os.path.join('..','dataframes_resources','dataframes_props.json')) as file:
    res = json.load(file)
column_order = res['column_order_dbs']

# %%
column_order
# Out:
# ['CID',
#  'HBondAcceptorCount',
#  'HBondDonorCount',
#  'IsomericSMILES',
#  'MolecularWeight',
#  'LogP',
#  'RuleFive',
#  'MATC_Code_Short',
#  'MATC_Code_Explanation']

# %%
pubchem.columns
# Out:
# Index(['Unnamed: 0', 'cid', 'cmpdname', 'cmpdsynonym', 'mw', 'mf', 'polararea',
#        'complexity', 'xlogp', 'heavycnt', 'hbonddonor', 'hbondacc', 'rotbonds',
#        'inchi', 'isosmiles', 'canonicalsmiles', 'inchikey', 'iupacname',
#        'exactmass', 'monoisotopicmass', 'charge', 'covalentunitcnt',
#        'isotopeatomcnt', 'totalatomstereocnt', 'definedatomstereocnt',
#        'undefinedatomstereocnt', 'totalbondstereocnt', 'definedbondstereocnt',
#        'undefinedbondstereocnt', 'pclidcnt', 'gpidcnt', 'gpfamilycnt',
#        'neighbortype', 'meshheadings', 'annothits', 'annothitcnt', 'aids',
#        'cidcdate', 'sidsrcname', 'depcatg', 'annotation'],
#       dtype='object')

# %%
pubchem_select = pubchem[['cid', 'hbondacc', 'hbonddonor', 'mw', 'xlogp', 'isosmiles']]

# %%
pubchem_select
# Out:
#      cid  hbondacc  hbonddonor      mw  xlogp
# 0      1         4           0  203.24    0.4  \
# 1    119         3           2  103.12   -3.2
# 2    137         4           2  131.13   -3.8
# 3    174         2           2   62.07   -1.4
# 4    176         2           1   60.05   -0.2
# ..   ...       ...         ...     ...    ...
# 95  2161         6           2  298.29    3.1
# 96  2162         7           2  408.90    3.0
# 97  2164         3           2  226.27    2.1
# 98  2165         4           2  355.90    2.6
# 99  2170         3           1  313.80    2.6
#
#                                             isosmiles
# 0                    CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C
# 1                                        C(CC(=O)O)CN
# 2                                   C(CC(=O)O)C(=O)CN
# 3                                              C(CO)O
# 4                                             CC(=O)O
# ..                                                ...
# 95     CC(C)C1=CC2=C(C=C1)OC3=NC(=C(C=C3C2=O)C(=O)O)N
# 96  CCOC(=O)C1=C(NC(=C(C1C2=CC=CC=C2Cl)C(=O)OC)C)C...
# 97                      CCC1(C(=O)NC(=O)NC1=O)CCC(C)C
# 98   CCN(CC)CC1=C(C=CC(=C1)NC2=C3C=CC(=CC3=NC=C2)Cl)O
# 99         C1CN(CCN1)C2=NC3=CC=CC=C3OC4=C2C=C(C=C4)Cl
#
# [100 rows x 6 columns]

# %%
pubchem_select = pubchem_select.rename(columns={'cid': 'CID', 'hbondacc': 'HBondAcceptorCount', 'hbonddonor': 'HBondDonorCount', 'mw': 'MolecularWeight', 'xlogp': 'LogP', 'isosmiles': 'IsomericSMILES'})

# %%
pubchem_select
# Out:
#      CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0      1                   4                0           203.24   0.4  \
# 1    119                   3                2           103.12  -3.2
# 2    137                   4                2           131.13  -3.8
# 3    174                   2                2            62.07  -1.4
# 4    176                   2                1            60.05  -0.2
# ..   ...                 ...              ...              ...   ...
# 95  2161                   6                2           298.29   3.1
# 96  2162                   7                2           408.90   3.0
# 97  2164                   3                2           226.27   2.1
# 98  2165                   4                2           355.90   2.6
# 99  2170                   3                1           313.80   2.6
#
#                                        IsomericSMILES
# 0                    CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C
# 1                                        C(CC(=O)O)CN
# 2                                   C(CC(=O)O)C(=O)CN
# 3                                              C(CO)O
# 4                                             CC(=O)O
# ..                                                ...
# 95     CC(C)C1=CC2=C(C=C1)OC3=NC(=C(C=C3C2=O)C(=O)O)N
# 96  CCOC(=O)C1=C(NC(=C(C1C2=CC=CC=C2Cl)C(=O)OC)C)C...
# 97                      CCC1(C(=O)NC(=O)NC1=O)CCC(C)C
# 98   CCN(CC)CC1=C(C=CC(=C1)NC2=C3C=CC(=CC3=NC=C2)Cl)O
# 99         C1CN(CCN1)C2=NC3=CC=CC=C3OC4=C2C=C(C=C4)Cl
#
# [100 rows x 6 columns]

# %%
# Set lipinski rules
hdonor = pubchem_select['HBondDonorCount'] < 6
haccept = pubchem_select['HBondAcceptorCount'] < 10
mw = pubchem_select['MolecularWeight'] < 500
clogP = pubchem_select['LogP'] < 5

# %%
# Apply rules to dataframe
pubchem_select['RuleFive'] = np.where(((hdonor & haccept & mw) | (hdonor & haccept & clogP) | (hdonor & mw & clogP) | (haccept & mw & clogP)), 1, 0)

# %%
pubchem_select
# Out:
#      CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0      1                   4                0           203.24   0.4  \
# 1    119                   3                2           103.12  -3.2
# 2    137                   4                2           131.13  -3.8
# 3    174                   2                2            62.07  -1.4
# 4    176                   2                1            60.05  -0.2
# ..   ...                 ...              ...              ...   ...
# 95  2161                   6                2           298.29   3.1
# 96  2162                   7                2           408.90   3.0
# 97  2164                   3                2           226.27   2.1
# 98  2165                   4                2           355.90   2.6
# 99  2170                   3                1           313.80   2.6
#
#                                        IsomericSMILES  RuleFive
# 0                    CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C         1
# 1                                        C(CC(=O)O)CN         1
# 2                                   C(CC(=O)O)C(=O)CN         1
# 3                                              C(CO)O         1
# 4                                             CC(=O)O         1
# ..                                                ...       ...
# 95     CC(C)C1=CC2=C(C=C1)OC3=NC(=C(C=C3C2=O)C(=O)O)N         1
# 96  CCOC(=O)C1=C(NC(=C(C1C2=CC=CC=C2Cl)C(=O)OC)C)C...         1
# 97                      CCC1(C(=O)NC(=O)NC1=O)CCC(C)C         1
# 98   CCN(CC)CC1=C(C=CC(=C1)NC2=C3C=CC(=CC3=NC=C2)Cl)O         1
# 99         C1CN(CCN1)C2=NC3=CC=CC=C3OC4=C2C=C(C=C4)Cl         1
#
# [100 rows x 7 columns]

# %%
not_found = []

# %%
def get_atc_code(cid):
    
    url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/{cid}/JSON'
    response = rq.get(url)
    pat = r"\"[A-Z]\d{2}[A-Z]{2}\d{2}\""
    atc_code_found = re.search(pat, response.text)
    if atc_code_found:
        return atc_code_found.group(0).strip('"')
    else:
        not_found.append(cid)

# %%
def get_atc_code_json(cid):
    url = f'https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/{cid}/JSON'
    response = rq.get(url)
    pat = r"\"[A-Z]\d{2}[A-Z]{2}\d{2}\""
    atc_code_found = re.search(pat, response.text)
    if atc_code_found:
        return atc_code_found.group(0).strip('"')

# %%
pubchem_select['ATC_Code'] = pubchem_select['CID'].map(get_atc_code)

# %%
not_found
# Out:
# [119, 174, 460, 1972]

# %%
len(not_found)
# Out:
# 4

# %%
pubchem_select
# Out:
#      CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0      1                   4                0           203.24   0.4  \
# 1    119                   3                2           103.12  -3.2
# 2    137                   4                2           131.13  -3.8
# 3    174                   2                2            62.07  -1.4
# 4    176                   2                1            60.05  -0.2
# ..   ...                 ...              ...              ...   ...
# 95  2161                   6                2           298.29   3.1
# 96  2162                   7                2           408.90   3.0
# 97  2164                   3                2           226.27   2.1
# 98  2165                   4                2           355.90   2.6
# 99  2170                   3                1           313.80   2.6
#
#                                        IsomericSMILES  RuleFive ATC_Code
# 0                    CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C         1  N06BX12
# 1                                        C(CC(=O)O)CN         1     None
# 2                                   C(CC(=O)O)C(=O)CN         1  L01XD04
# 3                                              C(CO)O         1     None
# 4                                             CC(=O)O         1  G01AD02
# ..                                                ...       ...      ...
# 95     CC(C)C1=CC2=C(C=C1)OC3=NC(=C(C=C3C2=O)C(=O)O)N         1  R03DX01
# 96  CCOC(=O)C1=C(NC(=C(C1C2=CC=CC=C2Cl)C(=O)OC)C)C...         1  C08CA01
# 97                      CCC1(C(=O)NC(=O)NC1=O)CCC(C)C         1  N05CA02
# 98   CCN(CC)CC1=C(C=CC(=C1)NC2=C3C=CC(=CC3=NC=C2)Cl)O         1  P01BA06
# 99         C1CN(CCN1)C2=NC3=CC=CC=C3OC4=C2C=C(C=C4)Cl         1  N06AA17
#
# [100 rows x 8 columns]

# %%
pubchem_select['MATC_Code_Short'] = pubchem_select['ATC_Code'].str[0]

# %%
with open(os.path.join('..','dataframes_resources','dataframes_props.json')) as file:
    res = json.load(file)
matc_codes_explanation = res['matc_codes_explanation']

# %%
pubchem_select['MATC_Code_Explanation'] = pubchem_select['MATC_Code_Short'].map(matc_codes_explanation)

# %%
pubchem_select = pubchem_select.drop('ATC_Code', axis=1)

# %%
pubchem_select = pubchem_select[pubchem_select['MATC_Code_Short'].isna() == False]

# %%
pubchem_select.head()
# Out:
#    CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight  LogP
# 0    1                   4                0           203.24   0.4  \
# 2  137                   4                2           131.13  -3.8
# 4  176                   2                1            60.05  -0.2
# 5  187                   2                0           146.21   0.2
# 6  237                   4                1           400.00   6.0
#
#                                       IsomericSMILES  RuleFive
# 0                   CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C         1  \
# 2                                  C(CC(=O)O)C(=O)CN         1
# 4                                            CC(=O)O         1
# 5                               CC(=O)OCC[N+](C)(C)C         1
# 6  CCN(CC)CCCC(C)NC1=C2C=C(C=CC2=NC3=C1C=CC(=C3)C...         1
#
#   MATC_Code_Short                              MATC_Code_Explanation
# 0               N                                     NERVOUS SYSTEM
# 2               L         ANTINEOPLASTIC AND IMMUNOMODULATING AGENTS
# 4               G             GENITO URINARY SYSTEM AND SEX HORMONES
# 5               S                                     SENSORY ORGANS
# 6               P  ANTIPARASITIC PRODUCTS, INSECTICIDES AND REPEL...
