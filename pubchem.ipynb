# %%
import numpy as np
import pandas as pd

# %%
pubchem = pd.read_xml('Compound_031500001_032000000.xml.gz', compression='gzip', parser ='etree')

# %%
from rdkit.Chem import PandasTools
pubchem = PandasTools.LoadSDF('Compound_052000001_052500000.sdf.gz', smilesName='SMILES', molColName='Molecule',
           includeFingerprints=True, removeHs=False, strictParsing=True)

# %%
pubchem.sample(10)
# Out:
#        PUBCHEM_COMPOUND_CID PUBCHEM_COMPOUND_CANONICALIZED  \
# 6055               52006948                              1
# 132236             52499077                              1
# 112833             52420476                              1
# 83592              52319891                              1
# 53420              52224181                              1
# 100624             52387796                              1
# 54441              52229203                              1
# 87780              52339018                              1
# 23066              52097953                              1
# 126768             52483671                              1
#
#        PUBCHEM_CACTVS_COMPLEXITY PUBCHEM_CACTVS_HBOND_ACCEPTOR  \
# 6055                         518                             7
# 132236                       431                             5
# 112833                       198                             3
# ...

# %%
pubchem.columns
# Out:
# Index(['PUBCHEM_COMPOUND_CID', 'PUBCHEM_COMPOUND_CANONICALIZED',
#        'PUBCHEM_CACTVS_COMPLEXITY', 'PUBCHEM_CACTVS_HBOND_ACCEPTOR',
#        'PUBCHEM_CACTVS_HBOND_DONOR', 'PUBCHEM_CACTVS_ROTATABLE_BOND',
#        'PUBCHEM_CACTVS_SUBSKEYS', 'PUBCHEM_IUPAC_OPENEYE_NAME',
#        'PUBCHEM_IUPAC_CAS_NAME', 'PUBCHEM_IUPAC_NAME_MARKUP',
#        'PUBCHEM_IUPAC_NAME', 'PUBCHEM_IUPAC_SYSTEMATIC_NAME',
#        'PUBCHEM_IUPAC_TRADITIONAL_NAME', 'PUBCHEM_IUPAC_INCHI',
#        'PUBCHEM_IUPAC_INCHIKEY', 'PUBCHEM_XLOGP3_AA', 'PUBCHEM_EXACT_MASS',
#        'PUBCHEM_MOLECULAR_FORMULA', 'PUBCHEM_MOLECULAR_WEIGHT',
#        'PUBCHEM_OPENEYE_CAN_SMILES', 'PUBCHEM_OPENEYE_ISO_SMILES',
#        'PUBCHEM_CACTVS_TPSA', 'PUBCHEM_MONOISOTOPIC_WEIGHT',
#        'PUBCHEM_TOTAL_CHARGE', 'PUBCHEM_HEAVY_ATOM_COUNT',
#        'PUBCHEM_ATOM_DEF_STEREO_COUNT', 'PUBCHEM_ATOM_UDEF_STEREO_COUNT',
#        'PUBCHEM_BOND_DEF_STEREO_COUNT', 'PUBCHEM_BOND_UDEF_STEREO_COUNT',
# ...

# %%
import os


list_of_dfs = []
for _, __, list_of_gz in os.walk('1213001_1214000'):
    for file in list_of_gz:
        df = pd.read_csv('1213001_1214000/1213001.csv.gz', compression='gzip')
        list_of_dfs.append(df.loc[2])

dfcomp = pd.DataFrame(list_of_dfs, columns=df1.index)
display(dfcomp)
# Out:
#    PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 2                   1  312466827.0   52939114.0
# 2                   1  312466827.0   52939114.0
# 2                   1  312466827.0   52939114.0
# 2                   1  312466827.0   52939114.0
# 2                   1  312466827.0   52939114.0
# ..                ...          ...          ...
# 2                   1  312466827.0   52939114.0
# 2                   1  312466827.0   52939114.0
# 2                   1  312466827.0   52939114.0
# 2                   1  312466827.0   52939114.0
# 2                   1  312466827.0   52939114.0
#
#                      PUBCHEM_EXT_DATASOURCE_SMILES PUBCHEM_ACTIVITY_OUTCOME  \
# 2   CC(C)N1C(=O)C=CC(=N1)C2=CN=C(N=C2C3=CC=CC=C3)N              Unspecified
# 2   CC(C)N1C(=O)C=CC(=N1)C2=CN=C(N=C2C3=CC=CC=C3)N              Unspecified
# 2   CC(C)N1C(=O)C=CC(=N1)C2=CN=C(N=C2C3=CC=CC=C3)N              Unspecified
# 2   CC(C)N1C(=O)C=CC(=N1)C2=CN=C(N=C2C3=CC=CC=C3)N              Unspecified
# ...

# %%
#dfcomp.info()
dfcomp[dfcomp['PUBCHEM_ACTIVITY_OUTCOME']=='Unspecified'].count()
# Out:
# PUBCHEM_RESULT_TAG               1000
# PUBCHEM_SID                      1000
# PUBCHEM_CID                      1000
# PUBCHEM_EXT_DATASOURCE_SMILES    1000
# PUBCHEM_ACTIVITY_OUTCOME         1000
# PUBCHEM_ACTIVITY_SCORE              0
# PUBCHEM_ACTIVITY_URL                0
# PUBCHEM_ASSAYDATA_COMMENT           0
# Standard Type                    1000
# Standard Relation                1000
# Standard Value                   1000
# Standard Units                   1000
# dtype: int64

# %%
df1 = df.loc[2]
df2 = df.loc[2]
df = pd.read_csv('1213001_1214000/1213001.csv.gz', compression='gzip')

# %%
df1.index
# Out:
# Index(['PUBCHEM_RESULT_TAG', 'PUBCHEM_SID', 'PUBCHEM_CID',
#        'PUBCHEM_EXT_DATASOURCE_SMILES', 'PUBCHEM_ACTIVITY_OUTCOME',
#        'PUBCHEM_ACTIVITY_SCORE', 'PUBCHEM_ACTIVITY_URL',
#        'PUBCHEM_ASSAYDATA_COMMENT', 'Standard Type', 'Standard Relation',
#        'Standard Value', 'Standard Units'],
#       dtype='object')

# %%
list_of_dfs = [df1,df2]
dfcomp = pd.DataFrame(list_of_dfs, columns=df1.index)
display(dfcomp)
# Out:
#   PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 2                  1  312466827.0   52939114.0
# 2                  1  312466827.0   52939114.0
#
#                     PUBCHEM_EXT_DATASOURCE_SMILES PUBCHEM_ACTIVITY_OUTCOME  \
# 2  CC(C)N1C(=O)C=CC(=N1)C2=CN=C(N=C2C3=CC=CC=C3)N              Unspecified
# 2  CC(C)N1C(=O)C=CC(=N1)C2=CN=C(N=C2C3=CC=CC=C3)N              Unspecified
#
#    PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  PUBCHEM_ASSAYDATA_COMMENT  \
# 2                     NaN                   NaN                        NaN
# 2                     NaN                   NaN                        NaN
#
#   Standard Type Standard Relation Standard Value Standard Units
# 2            CL                 =             34  mL.min-1.kg-1
# 2            CL                 =             34  mL.min-1.kg-1
