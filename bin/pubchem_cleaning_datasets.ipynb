# %%
import os
import json
import numpy as np
import pandas as pd

# %%
drugs = pd.read_csv('pubchem_all_atc.csv')

# %%
# Set lipinski rules
hdonor = drugs['HBondDonorCount'] < 6
haccept = drugs['HBondAcceptorCount'] < 10
mw = drugs['MolecularWeight'] < 500
clogP = drugs['LogP'] < 5
# Apply rules to dataframe
drugs['RuleFive'] = np.where(((hdonor & haccept & mw) | (hdonor & haccept & clogP) | (hdonor & mw & clogP) | (haccept & mw & clogP)), 1, 0)

# %%
drugs['ATC_Code'] = drugs['ATC_Code'].str[0]

# %%
with open(os.path.join('..','dataframes_resources','dataframes_props.json')) as file:
    res = json.load(file)
column_order = res['column_order']

# %%
drugs = drugs[column_order]

# %%
drugs
# Out:
#             CID  HBondAcceptorCount  HBondDonorCount  MolecularWeight   LogP
# 0             1                   4                0           203.24   0.40  \
# 1           119                   3                2           103.12  -3.17
# 2           137                   4                2           131.13  -1.50
# 3           176                   2                1            60.05  -0.17
# 4           187                   2                0           146.21   0.20
# ...         ...                 ...              ...              ...    ...
# 4370  168009818                  70               58          4813.00  -6.80
# 4371  168012238                  13                3           687.90   1.69
# 4372  168012331                  16                4          1030.30   4.25
# 4373  168013289                  56               24          2002.20 -10.50
# 4374  168013303                  16                3           828.00   2.90
#
#       RuleFive                                     IsomericSMILES ATC_Code
# 0            1                   CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C        N
# 1            1                                       C(CC(=O)O)CN        N
# 2            1                                  C(CC(=O)O)C(=O)CN        L
# 3            1                                            CC(=O)O        G
# 4            1                               CC(=O)OCC[N+](C)(C)C        S
# ...        ...                                                ...      ...
# 4370         0  CCC(C)C(C(=O)NC(C)C(=O)NC(CCC(=O)N)C(=O)NC(CCC...        A
# 4371         0  C[C@@H]1C[C@@H]([C@H]([C@@H](O1)OC2[C@H](C[C@@...        J
# 4372         0  C[C@@H]1CC[C@H]2C[C@@H](/C(=C/C=C/C=C\[C@H](C[...        L
# 4373         0  C(CSC[C@@H]1[C@@H]2[C@@H]([C@H]([C@H](O1)O[C@@...        V
# 4374         0  C[C@@H]1C/C=C/C=C/[C@@H]([C@@H](CC([C@@H]([C@H...        J
#
# [4375 rows x 8 columns]

# %%
drugs.to_csv(os.path.join('pubchem_label.csv'), index= False)
