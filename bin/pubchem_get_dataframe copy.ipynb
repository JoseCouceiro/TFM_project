# %%
import os
import json
import pandas as pd
import pubchempy as pcp

# %%
drugs = pd.read_csv('pubchem_atc.csv')

# %%
new_drugs = pd.read_csv('pubchem_2kon_atc.csv')

# %%
drugs = pd.concat([drugs, new_drugs])

# %%
drugs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3433 entries, 0 to 1912
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cid       3433 non-null   int64
#  1   name      3433 non-null   object
#  2   atc_code  3433 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 107.3+ KB

# %%
drugs = drugs.drop_duplicates()
drugs.to_csv('pubchem_atc_1981', index=False)

# %%
with open(os.path.join('..', 'dataframes_resources', 'dataframes_props.json')) as props:
    column_order = json.load(props)

# %%
column_order['column_order_pubchem']
# Out:
# ['CID',
#  'HBondAcceptorCount',
#  'HBondDonorCount',
#  'MolecularWeight',
#  'LogP',
#  'IsomericSMILES',
#  'ATC_Code']

# %%
drugs.head()
# Out:
#    cid                 name atc_code
# 0    1      Acetylcarnitine  N06BX12
# 1  137  Aminolevulinic acid  L01XD04
# 2  176          Acetic Acid  G01AD02
# 3  187        Acetylcholine  S01EB09
# 4  237           Quinacrine  P01AX05

# %%
toy_drugs = drugs[:20]
toy_drugs['compound'] = toy_drugs['cid'].map(pcp.Compound.from_cid)
toy_drugs.head()
# Out:
# C:\Users\josin\AppData\Local\Temp\ipykernel_16652\3789443155.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toy_drugs['compound'] = toy_drugs['cid'].map(pcp.Compound.from_cid)
#    cid                 name atc_code       compound
# 0    1      Acetylcarnitine  N06BX12    Compound(1)
# 1  137  Aminolevulinic acid  L01XD04  Compound(137)
# 2  176          Acetic Acid  G01AD02  Compound(176)
# 3  187        Acetylcholine  S01EB09  Compound(187)
# 4  237           Quinacrine  P01AX05  Compound(237)

# %%
toy_drugs[[
    'HBondAcceptorCount',
    'HBondDonorCount',
    'MolecularWeight',
    'LogP',
    'IsomericSMILES']] = toy_drugs['compound'].apply(lambda x: pd.Series([
        x.h_bond_acceptor_count,
        x.h_bond_donor_count, 
        x.molecular_weight,
        x.xlogp,
        x.isomeric_smiles]))
toy_drugs
# Out:
# C:\Users\josin\AppData\Local\Temp\ipykernel_16652\3950139149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toy_drugs[[
# C:\Users\josin\AppData\Local\Temp\ipykernel_16652\3950139149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toy_drugs[[
# C:\Users\josin\AppData\Local\Temp\ipykernel_16652\3950139149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toy_drugs[[
# C:\Users\josin\AppData\Local\Temp\ipykernel_16652\3950139149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toy_drugs[[
# C:\Users\josin\AppData\Local\Temp\ipykernel_16652\3950139149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toy_drugs[[
#     cid                  name atc_code       compound  HBondAcceptorCount
# 0     1       Acetylcarnitine  N06BX12    Compound(1)                   4  \
# 1   137   Aminolevulinic acid  L01XD04  Compound(137)                   4
# 2   176           Acetic Acid  G01AD02  Compound(176)                   2
# 3   187         Acetylcholine  S01EB09  Compound(187)                   2
# 4   237            Quinacrine  P01AX05  Compound(237)                   4
# 5   244        Benzyl Alcohol  P03AX06  Compound(244)                   1
# 6   247               Betaine  A16AA06  Compound(247)                   2
# 7   248       Loramine AMB-13  A16AA06  Compound(248)                   2
# 8   259           Bromide ion  N05CM11  Compound(259)                   1
# 9   280        Carbon Dioxide  V03AN02  Compound(280)                   2
# 10  281       Carbon Monoxide  V04CX08  Compound(281)                   1
# 11  311           Citric Acid  A09AB04  Compound(311)                   7
# 12  313     Hydrochloric Acid  A09AB03  Compound(313)                   0
# 13  338        Salicylic Acid  D01AE12  Compound(338)                   3
# 14  359        Phloroglucinol  A03AX12  Compound(359)                   3
# 15  444             Bupropion  N06AX12  Compound(444)                   2
# 16  454               Octanal  A07XA01  Compound(454)                   1
# 17  460              Guaiacol  R05CA08  Compound(460)                   2
# 18  546  Phosphonoacetic acid  J05AD02  Compound(546)                   5
# 19  564     Aminocaproic acid  B02AA01  Compound(564)                   3
#
#     HBondDonorCount MolecularWeight  LogP
# 0                 0          203.24   0.4  \
# 1                 2          131.13  -3.8
# 2                 1           60.05  -0.2
# 3                 0          146.21   0.2
# 4                 1           400.0   6.0
# 5                 1          108.14   1.1
# 6                 0          117.15   0.5
# 7                 1          118.15  -0.1
# 8                 0           79.90   1.0
# 9                 0          44.009   0.9
# 10                0          28.010   0.7
# 11                4          192.12  -1.7
# 12                1           36.46   0.8
# 13                2          138.12   2.3
# 14                3          126.11   0.2
# 15                1          239.74   3.2
# 16                0          128.21   2.7
# 17                1          124.14   1.3
# 18                3          140.03  -2.0
# 19                2          131.17  -3.0
#
#                                        IsomericSMILES
# 0                    CC(=O)OC(CC(=O)[O-])C[N+](C)(C)C
# 1                                   C(CC(=O)O)C(=O)CN
# 2                                             CC(=O)O
# 3                                CC(=O)OCC[N+](C)(C)C
# 4   CCN(CC)CCCC(C)NC1=C2C=C(C=CC2=NC3=C1C=CC(=C3)C...
# 5                                     C1=CC=C(C=C1)CO
# 6                               C[N+](C)(C)CC(=O)[O-]
# 7                                  C[N+](C)(C)CC(=O)O
# 8                                               [Br-]
# 9                                             C(=O)=O
# 10                                          [C-]#[O+]
# 11                       C(C(=O)O)C(CC(=O)O)(C(=O)O)O
# 12                                                 Cl
# 13                             C1=CC=C(C(=C1)C(=O)O)O
# 14                                 C1=C(C=C(C=C1O)O)O
# 15                  CC(C(=O)C1=CC(=CC=C1)Cl)NC(C)(C)C
# 16                                         CCCCCCCC=O
# 17                                     COC1=CC=CC=C1O
# 18                                 C(C(=O)O)P(=O)(O)O
# 19                                     C(CCC(=O)O)CCN
